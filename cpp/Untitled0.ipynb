# %%
# %matplotlib inline

# %%
f = open("results/early_sun_50x50_b4")
FGM = np.array([ [ float(e) for e in line.split() ] for line in f.readlines() ])

# %%
plt.matshow(FGM/2.7e-6, extent=(0, 31, -2.5, 0), interpolation='none', aspect='auto', vmin=0)
plt.colorbar()
plt.xlabel("$\Omega/\Omega_\odot$")
plt.ylabel("$\partial\log\Omega/\partial\log r$")
